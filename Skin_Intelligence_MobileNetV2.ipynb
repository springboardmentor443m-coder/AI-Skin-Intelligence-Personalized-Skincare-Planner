# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import pathlib
import matplotlib.pyplot as plt

DATA_DIR = "Data sets/skin_type"   # update to match your actual path

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

data_dir = pathlib.Path(DATA_DIR)
class_names = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])
print("Classes found:", class_names)
assert len(class_names) == 6, f"Expected 6 class folders, found {len(class_names)}: {class_names}"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 SEED = 42
#      13 data_dir = pathlib.Path(DATA_DIR)
# ---> 14 class_names = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])
#      15 print("Classes found:", class_names)
#      16 assert len(class_names) == 6, f"Expected 6 class folders, found {len(class_names)}: {class_names}"
#
# File ~\anaconda_projects\New folder\Lib\pathlib\_local.py:575, in Path.iterdir(self)
#     569 """Yield path objects of the directory contents.
#     570
#     571 The children are yielded in arbitrary order, and the
#     572 special entries '.' and '..' are not included.
#     573 """
#     574 root_dir = str(self)
# --> 575 with os.scandir(root_dir) as scandir_it:
#     576     paths = [entry.path for entry in scandir_it]
#     577 if root_dir == '.':
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Data sets\\skin_type'
