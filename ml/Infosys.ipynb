# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  10a_Hive_CRUD_Demo.gdoc
#  1771824764544429329246491275792.jpg
# '1(a)Exp.gdoc'
# '1(b)Exp (1).gdoc'
# '1(b)Exp (2).gdoc'
# '1(b)Exp.gdoc'
# '1(d)Exp.gdoc'
# '2025-11-08 13-56-08.mp4'
# '2025-11-08 13-56-09.mp4'
#  22501A4453.jpg
#  23501a4440.jpg
# "23501A4440 _--Today's Task .pdf"
#  4422.png
# '5th sem'
# '5th semester.pdf'
#  9-5-24-Task.pdf
#  9a_Theme_Demo.gdoc
#  9c_Custom_Widget_Example.gdoc
#  9e_Weather_API_Example.gdoc
#  aarav_and_meera_s_pink_city_portal.pdf
#  AI-Skin-Intelligence-Personalized-Skincare-Planner.zip
# 'AI Study Buddy Pro - Hackathon Submission Document.gdoc'
# 'azure code (1).gdoc'
# 'azure code.gdoc'
#  Binary-Beasts_CSD
#  buildathon.mp4
#  Buildathon_Video.mp4
#  certificates.pdf
#  Classroom
# 'CNS Question Bank .gdoc'
# 'cognifyz internship.zip'
# 'cognizant internship (1).zip'
# 'cognizant internship.zip'
# 'Colab Notebooks'
# 'Common LFA Final Hackathon Submission (1).gslides'
# 'Common LFA Final Hackathon Submission.gslides'
# ...

# %%
# !unzip "/content/drive/MyDrive/AI-Skin-Intelligence-Personalized-Skincare-Planner.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (26)_resized_rotated_180.jpg
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (27)_resized_rotated_90.jpg
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (28)_resized_flipped_horizontal.jpg
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (28)_resized_flipped_vertical.jpg
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (28)_resized_rotated_180.jpg
#   inflating: /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type/Test/Dry/images (29)_resized_rotated_90_flipped_horizontal.jpg
# ...

# %%
# %cd /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml
# Out:
# /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml

# %%
# !ls
# Out:
# dataset.py   model.py	 __pycache__	   skin_concern_model.pth  train.py
# evaluate.py  predict.py  requirements.txt  skin_type_model.pth

# %%
# !pip install -r requirements.txt

# %%
# !pwd
# Out:
# /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml

# %%
# !ls /content
# Out:
#  AI-Skin-Intelligence-Personalized-Skincare-Planner   drive
# 'Data sets'					      sample_data

# %%
# !ls "/content/AI-Skin-Intelligence-Personalized-Skincare-Planner"
# Out:
# 'AI_Skin Intelligence & Personalized Skincare Planner.pdf'   ml
# 'Data sets'						     README.md
#  LICENSE

# %%
# !ls "/content/AI-Skin-Intelligence-Personalized-Skincare-Planner/Data sets/Skin type"
# Out:
# Test  Train  Validation

# %%
# %cd /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml
# Out:
# /content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml

# %%
# !python train.py \
--data_dir "../Data sets/Skin type" \
--epochs 10 \
--save_path "skin_type_model.pth"
# Out:
# Using device: cuda
# Loading data from ../Data sets/Skin type...
# Classes: ['Combination', 'Dry', 'Normal', 'Oily', 'Sensitive']
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100% 20.5M/20.5M [00:00<00:00, 176MB/s]
#
# Epoch 1/10
# --------------------
# Training: 100% 266/266 [00:50<00:00,  5.32it/s, loss=1.3]
# Train Loss: 1.0010 Acc: 0.5369
# Validating: 100% 30/30 [00:02<00:00, 11.29it/s]
# Val Loss: 0.8143 Acc: 0.6130
# Saved new best model with accuracy 0.6130
#
# Epoch 2/10
# --------------------
# Training: 100% 266/266 [00:48<00:00,  5.54it/s, loss=5.68]
# Train Loss: 0.8590 Acc: 0.6241
# Validating: 100% 30/30 [00:03<00:00,  8.79it/s]
# Val Loss: 0.7657 Acc: 0.6423
# Saved new best model with accuracy 0.6423
#
# Epoch 3/10
# --------------------
# Training: 100% 266/266 [00:48<00:00,  5.51it/s, loss=5.09]
# Train Loss: 0.7681 Acc: 0.6595
# ...

# %%
# !python train.py \
--data_dir "../Data sets/Skin concerns" \
--epochs 10 \
--save_path "skin_concern_model.pth"
# Out:
# Using device: cuda
# Loading data from ../Data sets/Skin concerns...
# Classes: ['Normal', 'Redness', 'dark spots', 'inflammatory acne', 'non inflammatory acne black heads', 'non inflammatory acne white heads', 'pigmentation', 'pores', 'wrinkles']
#
# Epoch 1/10
# --------------------
# Training: 100% 337/337 [01:18<00:00,  4.28it/s, loss=0.671]
# Train Loss: 0.9246 Acc: 0.6913
# Validating: 100% 30/30 [00:05<00:00,  5.48it/s]
# Val Loss: 0.5028 Acc: 0.7885
# Saved new best model with accuracy 0.7885
#
# Epoch 2/10
# --------------------
# Training: 100% 337/337 [01:18<00:00,  4.27it/s, loss=0.657]
# Train Loss: 0.6563 Acc: 0.7771
# Validating: 100% 30/30 [00:04<00:00,  6.30it/s]
# Val Loss: 0.5268 Acc: 0.8056
# Saved new best model with accuracy 0.8056
#
# Epoch 3/10
# --------------------
# Training: 100% 337/337 [01:18<00:00,  4.30it/s, loss=0.851]
# Train Loss: 0.5650 Acc: 0.8062
# Validating: 100% 30/30 [00:04<00:00,  6.10it/s]
# Val Loss: 0.2913 Acc: 0.8782
# ...

# %%
from google.colab import files

files.download("skin_concern_model.pth")

# %%
# !find .. -name "c2_resized_flipped_horizontal.jpg"
# Out:
# ../Data sets/Skin type/Test/Oily/c2_resized_flipped_horizontal.jpg

# %%
# !python predict.py "../Data sets/Skin type/Test/Oily/c2_resized_flipped_horizontal.jpg"
# Out:
# Analyzing image: ../Data sets/Skin type/Test/Oily/c2_resized_flipped_horizontal.jpg
# Traceback (most recent call last):
#   File "/content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml/predict.py", line 78, in <module>
#     final_analysis = analyze_skin(img_path, type_model_file, concern_model_file)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml/predict.py", line 61, in analyze_skin
#     concern_model = load_model(concern_model_path, num_classes=len(concern_classes))
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/AI-Skin-Intelligence-Personalized-Skincare-Planner/ml/predict.py", line 11, in load_model
#     model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2639, in load_state_dict
# ...

# %%
from google.colab import files
files.download("skin_type_model.pth")
